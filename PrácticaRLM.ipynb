# %% [markdown]
# # Práctica regresión lineal multivariada
#
# **Nombre:** Rafael Isaac Cano Guitton
#
# ## Lectura de datos
#
# Para los experimentos de la presente se escogió un conjunto de datos que se usa como para regresión multivariada en kaggle. El dataset se llama Home Sales in King County, USA. El cual se encuentra en el siguiente enlace:
# https://www.kaggle.com/code/divan0/multiple-linear-regression/data?select=kc_house_data.csv
# Para la implementación se usan las librerías:
#
# - Numpy
# - Pandas

# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("kc_house_data.csv")
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
import seaborn as sns
with sns.plotting_context("notebook",font_scale=2.5):
    g = sns.pairplot(dataset[['sqft_lot','sqft_above','price','sqft_living','bedrooms']], 
                 hue='bedrooms', palette='tab20',size=6)
g.set(xticklabels=[])
# Out:
# /Users/rafxar/topicosIA/topicos/lib/python3.9/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
